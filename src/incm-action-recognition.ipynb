# %%
import os
import cv2
import json
import matplotlib.pyplot as plt
import numpy as np
import random
import time
import torch
import torch.nn as nn
import torch.optim as optim

from datetime import datetime
from pathlib import Path
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from typing import Tuple, List, Dict

# %%
class UCF11Dataset(Dataset):
    """
    Dataset class for UCF11 action recognition dataset
    """
    def __init__(self, 
                 root_dir: str, 
                 frames_per_clip: int = 30,
                 frame_size: Tuple[int, int] = (64, 64),
                 train: bool = True,
                 train_split: float = 0.8,
                 transform=None):
        """
        Args:
            root_dir (str): Root directory of UCF11 dataset
            frames_per_clip (int): Number of frames to sample from each video
            frame_size (tuple): Size to resize frames to
            train (bool): Whether this is training or validation set
            train_split (float): Fraction of data to use for training
            transform: Optional transform to be applied on frames
        """
        self.root_dir = Path(root_dir)
        self.frames_per_clip = frames_per_clip
        self.frame_size = frame_size
        self.transform = transform
        
        # Get all action categories (folders)
        self.action_categories = sorted([d for d in os.listdir(self.root_dir) 
                                      if os.path.isdir(self.root_dir / d)])
        
        # Create class to index mapping
        self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(self.action_categories)}
        
        # Collect all video paths and their corresponding labels
        self.video_paths = []
        self.labels = []
        
        for category in self.action_categories:
            category_path = self.root_dir / category
            # Get all group folders
            group_folders = [d for d in os.listdir(category_path) 
                           if os.path.isdir(category_path / d)]
            
            for group in group_folders:
                group_path = category_path / group
                # Get all videos in this group
                videos = [f for f in os.listdir(group_path) if f.endswith('.mpg')]
                
                for video in videos:
                    self.video_paths.append(str(group_path / video))
                    self.labels.append(self.class_to_idx[category])
        
        # Split into train and validation sets
        num_videos = len(self.video_paths)
        indices = list(range(num_videos))
        random.seed(42)  # for reproducibility
        random.shuffle(indices)
        split = int(train_split * num_videos)
        
        if train:
            self.indices = indices[:split]
        else:
            self.indices = indices[split:]
            
        print(f"{'Training' if train else 'Validation'} set contains {len(self.indices)} videos")
        
    def __len__(self) -> int:
        return len(self.indices)
    
    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        # Get the actual index from our train/val split
        actual_idx = self.indices[idx]
        
        # Load video and label
        video_path = self.video_paths[actual_idx]
        label = self.labels[actual_idx]
        
        # Load and preprocess video frames
        frames = self.load_video(video_path)
        
        # Convert to tensor and adjust dimensions
        frames = torch.FloatTensor(frames)
        frames = frames.permute(0, 3, 1, 2)  # [T, H, W, C] -> [T, C, H, W]
        
        if self.transform:
            frames = self.transform(frames)
        
        return frames, torch.tensor(label, dtype=torch.long)
    
    def load_video(self, path: str) -> np.ndarray:
        """Load video and return preprocessed frames"""
        cap = cv2.VideoCapture(path)
        frames = []
        
        try:
            while len(frames) < self.frames_per_clip:
                ret, frame = cap.read()
                if not ret:
                    break
                    
                # Preprocess frame
                frame = self.preprocess_frame(frame)
                frames.append(frame)
                
            # Handle videos shorter than desired length
            if len(frames) < self.frames_per_clip:
                # Duplicate last frame if video is too short
                last_frame = frames[-1]
                while len(frames) < self.frames_per_clip:
                    frames.append(last_frame)
                    
        finally:
            cap.release()
            
        return np.array(frames)
    
    def preprocess_frame(self, frame: np.ndarray) -> np.ndarray:
        """Preprocess a single frame"""
        # Center crop
        frame = self.crop_center_square(frame)
        # Resize
        frame = cv2.resize(frame, self.frame_size)
        # Convert BGR to RGB
        frame = frame[:, :, [2, 1, 0]]
        # Normalize
        frame = frame / 255.0
        
        return frame
    
    @staticmethod
    def crop_center_square(frame: np.ndarray) -> np.ndarray:
        """Crop the center square from a frame"""
        y, x = frame.shape[0:2]
        min_dim = min(y, x)
        start_x = (x // 2) - (min_dim // 2)
        start_y = (y // 2) - (min_dim // 2)
        return frame[start_y:start_y+min_dim, start_x:start_x+min_dim]
    
    def get_class_names(self) -> List[str]:
        """Return list of class names"""
        return self.action_categories

# %%
def create_dataloaders(root_dir: str, 
                      batch_size: int = 32,
                      frames_per_clip: int = 30,
                      frame_size: Tuple[int, int] = (64, 64),
                      num_workers: int = 4) -> Tuple[DataLoader, DataLoader]:
    """
    Create training and validation dataloaders
    
    Args:
        root_dir: Root directory of UCF11 dataset
        batch_size: Batch size for dataloaders
        frames_per_clip: Number of frames to sample from each video
        frame_size: Size to resize frames to
        num_workers: Number of worker processes for data loading
        
    Returns:
        train_loader, val_loader: Training and validation dataloaders
    """
    # Create training dataset
    train_dataset = UCF11Dataset(
        root_dir=root_dir,
        frames_per_clip=frames_per_clip,
        frame_size=frame_size,
        train=True
    )
    
    # Create validation dataset
    val_dataset = UCF11Dataset(
        root_dir=root_dir,
        frames_per_clip=frames_per_clip,
        frame_size=frame_size,
        train=False
    )
    
    # Create dataloaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    )
    
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )
    
    return train_loader, val_loader

# %%
class ConvLSTM(nn.Module):
    def __init__(self, input_channels: int = 3, hidden_channels: int = 64, kernel_size: int = 3):
        super(ConvLSTM, self).__init__()
        self.conv_lstm = nn.Sequential(
            nn.Conv3d(input_channels, hidden_channels, kernel_size=(3, kernel_size, kernel_size), 
                     padding=(1, kernel_size//2, kernel_size//2)),
            nn.BatchNorm3d(hidden_channels),
            nn.ReLU(inplace=True)
        )
        self.dropout1 = nn.Dropout(0.2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(hidden_channels * 64 * 64, 256)
        self.dropout2 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(256, 11)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x shape: [batch_size, time_steps, channels, height, width]
        x = x.permute(0, 2, 1, 3, 4)  # [batch_size, channels, time_steps, height, width]
        x = self.conv_lstm(x)
        x = x.mean(dim=2)  # Average over temporal dimension
        x = self.dropout1(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        return x

# %%
class ConvFF(nn.Module):
    def __init__(self, input_channels: int = 3, hidden_channels: int = 64, kernel_size: int = 3):
        super(ConvFF, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv3d(input_channels, hidden_channels, kernel_size=(3, kernel_size, kernel_size),
                     padding=(1, kernel_size//2, kernel_size//2)),
            nn.BatchNorm3d(hidden_channels),
            nn.ReLU(inplace=True)
        )
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(hidden_channels * 64 * 64, 256)
        self.fc2 = nn.Linear(256, 11)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.permute(0, 2, 1, 3, 4)  # [batch_size, channels, time_steps, height, width]
        x = self.conv(x)
        x = x.mean(dim=2)  # Average over temporal dimension
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
class Trainer:
    def __init__(self,
                 model: nn.Module,
                 train_loader: DataLoader,
                 val_loader: DataLoader,
                 criterion: nn.Module = None,
                 optimizer: optim.Optimizer = None,
                 lr: float = 0.001,
                 num_epochs: int = 30,
                 device: str = None,
                 model_name: str = "model",
                 save_dir: str = "checkpoints"):
        """
        Initialize the trainer
        
        Args:
            model: PyTorch model to train
            train_loader: Training data loader
            val_loader: Validation data loader
            criterion: Loss function (default: CrossEntropyLoss)
            optimizer: Optimizer (default: Adam)
            lr: Learning rate
            num_epochs: Number of epochs to train
            device: Device to train on (default: auto-detect)
            model_name: Name for saving model checkpoints
            save_dir: Directory to save checkpoints and logs
        """
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.criterion = criterion if criterion else nn.CrossEntropyLoss()
        self.optimizer = optimizer if optimizer else optim.Adam(model.parameters(), lr=lr)
        self.num_epochs = num_epochs
        self.device = device if device else ('cuda' if torch.cuda.is_available() else 'cpu')
        self.model_name = model_name
        self.save_dir = Path(save_dir)
        self.save_dir.mkdir(exist_ok=True)
        
        # Move model to device
        self.model = self.model.to(self.device)
        
        # Initialize tracking variables
        self.train_losses = []
        self.train_accuracies = []
        self.val_losses = []
        self.val_accuracies = []
        self.best_val_acc = 0.0
        
        # Create log directory with timestamp
        self.timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        self.log_dir = self.save_dir / f"{self.model_name}_{self.timestamp}"
        self.log_dir.mkdir(exist_ok=True)
        
        self.log_every_n_batches = 40
        self.gradient_accumulation_steps = 4
        
    def train_epoch(self):
        self.model.train()
        running_loss = 0.0
        running_acc = 0.0
        total_batches = len(self.train_loader)
        
        # Reset gradients
        self.optimizer.zero_grad()
        
        for batch_idx, (inputs, labels) in enumerate(self.train_loader):
            # Move data to device
            inputs, labels = inputs.to(self.device), labels.to(self.device)
            
            # Forward pass
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels) / self.gradient_accumulation_steps
            
            # Backward pass
            loss.backward()
            
            # Only optimize every n steps
            if (batch_idx + 1) % self.gradient_accumulation_steps == 0:
                self.optimizer.step()
                self.optimizer.zero_grad()
            
            # Calculate accuracy
            with torch.no_grad():
                _, predicted = torch.max(outputs.data, 1)
                acc = (predicted == labels).sum().item() / labels.size(0)
            
            # Update running metrics
            running_loss += loss.item() * self.gradient_accumulation_steps
            running_acc += acc
            
            # Print progress less frequently
            if (batch_idx + 1) % self.log_every_n_batches == 0:
                print(f'Batch [{batch_idx + 1}/{total_batches}] - '
                      f'Loss: {loss.item() * self.gradient_accumulation_steps:.4f} - Acc: {acc:.4f}')
            
            # Clear cache periodically
            if (batch_idx + 1) % 10 == 0:
                torch.cuda.empty_cache()
        
        epoch_loss = running_loss / total_batches
        epoch_acc = running_acc / total_batches
        return epoch_loss, epoch_acc
    
    @torch.no_grad()
    def validate(self) -> Tuple[float, float]:
        """Validate the model"""
        self.model.eval()
        running_loss = 0.0
        running_acc = 0.0
        total_batches = len(self.val_loader)
        
        for inputs, labels in self.val_loader:
            inputs, labels = inputs.to(self.device), labels.to(self.device)
            
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            
            _, predicted = torch.max(outputs.data, 1)
            acc = (predicted == labels).sum().item() / labels.size(0)
            
            running_loss += loss.item()
            running_acc += acc
        
        val_loss = running_loss / total_batches
        val_acc = running_acc / total_batches
        return val_loss, val_acc
    
    def train(self):
        """Train the model for the specified number of epochs"""
        print(f"Training on {self.device}")
        print(f"Model: {self.model_name}")
        
        for epoch in range(self.num_epochs):
            print(f"\nEpoch {epoch + 1}/{self.num_epochs}")
            print("-" * 20)
            
            # Training phase
            epoch_start = time.time()
            train_loss, train_acc = self.train_epoch()
            epoch_time = time.time() - epoch_start
            
            # Validation phase
            val_loss, val_acc = self.validate()
            
            # Store metrics
            self.train_losses.append(train_loss)
            self.train_accuracies.append(train_acc)
            self.val_losses.append(val_loss)
            self.val_accuracies.append(val_acc)
            
            # Print epoch summary
            print(f"\nEpoch Summary:")
            print(f"Time taken: {epoch_time:.2f}s")
            print(f"Train Loss: {train_loss:.4f} - Train Acc: {train_acc:.4f}")
            print(f"Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.4f}")
            
            # Save best model
            if val_acc > self.best_val_acc:
                self.best_val_acc = val_acc
                self.save_checkpoint(f"best_{self.model_name}.pth")
            
#             # Save regular checkpoint
#             if (epoch + 1) % 10 == 0:
#                 self.save_checkpoint(f"{self.model_name}_epoch_{epoch + 1}.pth")
            
            # Save metrics
            self.save_metrics()
            
            # Plot and save learning curves
            self.plot_learning_curves()
    
    def save_checkpoint(self, filename: str):
        """Save model checkpoint"""
        checkpoint = {
            'epoch': len(self.train_losses),
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_losses': self.train_losses,
            'train_accuracies': self.train_accuracies,
            'val_losses': self.val_losses,
            'val_accuracies': self.val_accuracies,
            'best_val_acc': self.best_val_acc
        }
        torch.save(checkpoint, self.log_dir / filename)
    
    def save_metrics(self):
        """Save training metrics to JSON"""
        metrics = {
            'train_losses': self.train_losses,
            'train_accuracies': self.train_accuracies,
            'val_losses': self.val_losses,
            'val_accuracies': self.val_accuracies,
            'best_val_acc': self.best_val_acc
        }
        with open(self.log_dir / 'metrics.json', 'w') as f:
            json.dump(metrics, f, indent=4)
    
    def plot_learning_curves(self):
        """Plot and save learning curves"""
        plt.figure(figsize=(12, 5))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(self.train_losses, label='Train Loss')
        plt.plot(self.val_losses, label='Val Loss')
        plt.title('Loss vs. Epoch')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot accuracy
        plt.subplot(1, 2, 2)
        plt.plot(self.train_accuracies, label='Train Acc')
        plt.plot(self.val_accuracies, label='Val Acc')
        plt.title('Accuracy vs. Epoch')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig(self.log_dir / 'learning_curves.png')
        plt.close()
        
    @staticmethod
    def plot_separate_curves(model_name, metrics, save_dir):
        """Plot separate learning curves for a single model"""
        plt.figure(figsize=(12, 5))
        
        # Plot accuracy
        plt.subplot(1, 2, 1)
        plt.plot(metrics['train_accuracies'], label='Train')
        plt.plot(metrics['val_accuracies'], label='Validation')
        plt.title(f'{model_name} - Accuracy vs. Epoch')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        
        # Plot loss
        plt.subplot(1, 2, 2)
        plt.plot(metrics['train_losses'], label='Train')
        plt.plot(metrics['val_losses'], label='Validation')
        plt.title(f'{model_name} - Loss vs. Epoch')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig(save_dir / f'{model_name}_curves.png')
        plt.close()
        
    @staticmethod
    def plot_combined_curves(metrics_dict, save_dir):
        """Plot combined learning curves for multiple models"""
        plt.figure(figsize=(12, 5))
        
        # Plot accuracy
        plt.subplot(1, 2, 1)
        for model_name, metrics in metrics_dict.items():
            plt.plot(metrics['train_accuracies'], label=f'{model_name} Train')
            plt.plot(metrics['val_accuracies'], label=f'{model_name} Val')
        plt.title('Combined Accuracy vs. Epoch')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        
        # Plot loss
        plt.subplot(1, 2, 2)
        for model_name, metrics in metrics_dict.items():
            plt.plot(metrics['train_losses'], label=f'{model_name} Train')
            plt.plot(metrics['val_losses'], label=f'{model_name} Val')
        plt.title('Combined Loss vs. Epoch')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        plt.tight_layout()
        plt.savefig(save_dir / 'combined_curves.png')
        plt.close()

# %%
root_dir = "/kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg"
batch_size = 32
frames_per_clip = 30
frame_size = (64, 64)
num_epochs = 100
all_metrics = {}

plots_dir = Path("plots_comparison")
plots_dir.mkdir(exist_ok=True)

# Create dataloaders
train_loader, val_loader = create_dataloaders(
    root_dir=root_dir,
    batch_size=batch_size // 2,  # Reduce batch size to save memory
    frames_per_clip=frames_per_clip,
    frame_size=frame_size,
    num_workers=2  # Reduce number of workers
)


# Print dataset information
print(f"Number of training batches: {len(train_loader)}")
print(f"Number of validation batches: {len(val_loader)}")

# Get class names
class_names = train_loader.dataset.get_class_names()
print("\nAction categories:")
for idx, name in enumerate(class_names):
    print(f"{idx}: {name}")

print("Training ConvLSTM model...")
convlstm_model = ConvLSTM()
convlstm_trainer = Trainer(
    model=convlstm_model,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=num_epochs,
    model_name="convlstm",
    save_dir="model_comparison"
)
convlstm_trainer.train()

all_metrics['ConvLSTM'] = {
    'train_losses': convlstm_trainer.train_losses,
    'train_accuracies': convlstm_trainer.train_accuracies,
    'val_losses': convlstm_trainer.val_losses,
    'val_accuracies': convlstm_trainer.val_accuracies
}

Trainer.plot_separate_curves('ConvLSTM', all_metrics['ConvLSTM'], plots_dir)
    
del convlstm_model, convlstm_trainer
torch.cuda.empty_cache()

# Train ConvFF
print("\nTraining ConvFF model...")
convff_model = ConvFF()
convff_trainer = Trainer(
    model=convff_model,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=num_epochs,
    model_name="convff",
    save_dir="model_comparison"
)
convff_trainer.train()

all_metrics['ConvFF'] = {
    'train_losses': convff_trainer.train_losses,
    'train_accuracies': convff_trainer.train_accuracies,
    'val_losses': convff_trainer.val_losses,
    'val_accuracies': convff_trainer.val_accuracies
}

# Plot separate curves for ConvFF
Trainer.plot_separate_curves('ConvFF', all_metrics['ConvFF'], plots_dir)

# Plot combined curves
Trainer.plot_combined_curves(all_metrics, plots_dir)

print("\nTraining complete! Plots have been saved to the 'model_comparison' directory.")
# Out:
# Training set contains 1280 videos
# Validation set contains 320 videos
# Number of training batches: 80
# Number of validation batches: 20
#
# Action categories:
# 0: basketball
# 1: biking
# 2: diving
# 3: golf_swing
# 4: horse_riding
# 5: soccer_juggling
# 6: swing
# 7: tennis_swing
# 8: trampoline_jumping
# 9: volleyball_spiking
# 10: walking
# Training ConvLSTM model...
# Training on cuda
# Model: convlstm
#
# Epoch 1/100
# --------------------
# Batch [40/80] - Loss: 125.8959 - Acc: 0.2500
# Batch [80/80] - Loss: 63.2646 - Acc: 0.3750
#
# Epoch Summary:
# Time taken: 11.63s
# Train Loss: 105.1894 - Train Acc: 0.2539
# Val Loss: 43.8414 - Val Acc: 0.3531
#
# Epoch 2/100
# --------------------
# Batch [40/80] - Loss: 21.7685 - Acc: 0.6250
# Batch [80/80] - Loss: 17.7790 - Acc: 0.5625
#
# Epoch Summary:
# Time taken: 11.61s
# Train Loss: 26.9333 - Train Acc: 0.5391
# Val Loss: 20.5713 - Val Acc: 0.5188
#
# Epoch 3/100
# --------------------
# Batch [40/80] - Loss: 7.9154 - Acc: 0.6875
# Batch [80/80] - Loss: 0.7416 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.20s
# Train Loss: 9.6948 - Train Acc: 0.6945
# Val Loss: 15.1189 - Val Acc: 0.5969
#
# Epoch 4/100
# --------------------
# Batch [40/80] - Loss: 9.3996 - Acc: 0.6875
# Batch [80/80] - Loss: 5.3704 - Acc: 0.7500
#
# Epoch Summary:
# Time taken: 11.89s
# Train Loss: 7.5297 - Train Acc: 0.7078
# Val Loss: 11.4240 - Val Acc: 0.6094
#
# Epoch 5/100
# --------------------
# Batch [40/80] - Loss: 5.5494 - Acc: 0.8125
# Batch [80/80] - Loss: 4.9369 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.93s
# Train Loss: 6.1580 - Train Acc: 0.7789
# Val Loss: 17.4650 - Val Acc: 0.6156
#
# Epoch 6/100
# --------------------
# Batch [40/80] - Loss: 6.8257 - Acc: 0.8125
# Batch [80/80] - Loss: 9.5710 - Acc: 0.7500
#
# Epoch Summary:
# Time taken: 11.77s
# Train Loss: 6.8390 - Train Acc: 0.7719
# Val Loss: 16.2218 - Val Acc: 0.6125
#
# Epoch 7/100
# --------------------
# Batch [40/80] - Loss: 10.3283 - Acc: 0.6875
# Batch [80/80] - Loss: 13.8780 - Acc: 0.6875
#
# Epoch Summary:
# Time taken: 12.03s
# Train Loss: 5.5884 - Train Acc: 0.7984
# Val Loss: 13.2756 - Val Acc: 0.7000
#
# Epoch 8/100
# --------------------
# Batch [40/80] - Loss: 1.5306 - Acc: 0.8125
# Batch [80/80] - Loss: 8.3477 - Acc: 0.7500
#
# Epoch Summary:
# Time taken: 11.96s
# Train Loss: 5.4756 - Train Acc: 0.8117
# Val Loss: 11.0569 - Val Acc: 0.6625
#
# Epoch 9/100
# --------------------
# Batch [40/80] - Loss: 6.4876 - Acc: 0.8750
# Batch [80/80] - Loss: 0.0040 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.07s
# Train Loss: 2.7895 - Train Acc: 0.8781
# Val Loss: 15.1138 - Val Acc: 0.6125
#
# Epoch 10/100
# --------------------
# Batch [40/80] - Loss: 5.9410 - Acc: 0.7500
# Batch [80/80] - Loss: 4.5519 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.73s
# Train Loss: 2.0137 - Train Acc: 0.9078
# Val Loss: 8.9881 - Val Acc: 0.7063
#
# Epoch 11/100
# --------------------
# Batch [40/80] - Loss: 0.3725 - Acc: 0.9375
# Batch [80/80] - Loss: 1.9826 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.67s
# Train Loss: 1.5280 - Train Acc: 0.9242
# Val Loss: 9.7201 - Val Acc: 0.7094
#
# Epoch 12/100
# --------------------
# Batch [40/80] - Loss: 0.5721 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0042 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.44s
# Train Loss: 1.2400 - Train Acc: 0.9203
# Val Loss: 8.7861 - Val Acc: 0.7188
#
# Epoch 13/100
# --------------------
# Batch [40/80] - Loss: 1.4913 - Acc: 0.9375
# Batch [80/80] - Loss: 4.4157 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.75s
# Train Loss: 1.2571 - Train Acc: 0.9344
# Val Loss: 9.1830 - Val Acc: 0.7250
#
# Epoch 14/100
# --------------------
# Batch [40/80] - Loss: 1.0961 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.54s
# Train Loss: 0.8921 - Train Acc: 0.9359
# Val Loss: 9.5871 - Val Acc: 0.7156
#
# Epoch 15/100
# --------------------
# Batch [40/80] - Loss: 0.0553 - Acc: 0.9375
# Batch [80/80] - Loss: 3.9561 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.73s
# Train Loss: 0.8347 - Train Acc: 0.9445
# Val Loss: 11.0536 - Val Acc: 0.6969
#
# Epoch 16/100
# --------------------
# Batch [40/80] - Loss: 0.1852 - Acc: 0.9375
# Batch [80/80] - Loss: 0.8921 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.95s
# Train Loss: 0.8922 - Train Acc: 0.9469
# Val Loss: 10.0624 - Val Acc: 0.7031
#
# Epoch 17/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.1575 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.29s
# Train Loss: 0.4033 - Train Acc: 0.9664
# Val Loss: 9.3369 - Val Acc: 0.7312
#
# Epoch 18/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.1053 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.72s
# Train Loss: 0.4506 - Train Acc: 0.9672
# Val Loss: 11.5690 - Val Acc: 0.7156
#
# Epoch 19/100
# --------------------
# Batch [40/80] - Loss: 0.0969 - Acc: 0.9375
# Batch [80/80] - Loss: 0.1994 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.47s
# Train Loss: 0.5954 - Train Acc: 0.9617
# Val Loss: 14.4252 - Val Acc: 0.6656
#
# Epoch 20/100
# --------------------
# Batch [40/80] - Loss: 0.8259 - Acc: 0.9375
# Batch [80/80] - Loss: 1.2248 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.22s
# Train Loss: 0.9459 - Train Acc: 0.9492
# Val Loss: 13.2867 - Val Acc: 0.6813
#
# Epoch 21/100
# --------------------
# Batch [40/80] - Loss: 1.1792 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.57s
# Train Loss: 0.7648 - Train Acc: 0.9453
# Val Loss: 13.5822 - Val Acc: 0.6687
#
# Epoch 22/100
# --------------------
# Batch [40/80] - Loss: 0.0006 - Acc: 1.0000
# Batch [80/80] - Loss: 0.6067 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 14.09s
# Train Loss: 0.8077 - Train Acc: 0.9570
# Val Loss: 9.9425 - Val Acc: 0.6969
#
# Epoch 23/100
# --------------------
# Batch [40/80] - Loss: 4.9746 - Acc: 0.8125
# Batch [80/80] - Loss: 0.3974 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.96s
# Train Loss: 1.3024 - Train Acc: 0.9297
# Val Loss: 15.9746 - Val Acc: 0.6531
#
# Epoch 24/100
# --------------------
# Batch [40/80] - Loss: 0.8350 - Acc: 0.9375
# Batch [80/80] - Loss: 5.3031 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 12.96s
# Train Loss: 1.9426 - Train Acc: 0.9234
# Val Loss: 13.5896 - Val Acc: 0.6719
#
# Epoch 25/100
# --------------------
# Batch [40/80] - Loss: 6.9442 - Acc: 0.8125
# Batch [80/80] - Loss: 0.0008 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.46s
# Train Loss: 2.1272 - Train Acc: 0.9109
# Val Loss: 13.0165 - Val Acc: 0.6937
#
# Epoch 26/100
# --------------------
# Batch [40/80] - Loss: 2.7134 - Acc: 0.9375
# Batch [80/80] - Loss: 2.6074 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.67s
# Train Loss: 1.0424 - Train Acc: 0.9367
# Val Loss: 14.0777 - Val Acc: 0.6937
#
# Epoch 27/100
# --------------------
# Batch [40/80] - Loss: 0.0426 - Acc: 1.0000
# Batch [80/80] - Loss: 1.7609 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.36s
# Train Loss: 0.7221 - Train Acc: 0.9563
# Val Loss: 14.4710 - Val Acc: 0.6781
#
# Epoch 28/100
# --------------------
# Batch [40/80] - Loss: 0.8769 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.22s
# Train Loss: 0.8173 - Train Acc: 0.9484
# Val Loss: 12.1830 - Val Acc: 0.7156
#
# Epoch 29/100
# --------------------
# Batch [40/80] - Loss: 3.6004 - Acc: 0.8125
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.74s
# Train Loss: 0.8762 - Train Acc: 0.9547
# Val Loss: 12.3230 - Val Acc: 0.7031
#
# Epoch 30/100
# --------------------
# Batch [40/80] - Loss: 0.9370 - Acc: 0.9375
# Batch [80/80] - Loss: 0.2600 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.81s
# Train Loss: 0.6647 - Train Acc: 0.9633
# Val Loss: 12.0485 - Val Acc: 0.7000
#
# Epoch 31/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.20s
# Train Loss: 0.3422 - Train Acc: 0.9711
# Val Loss: 11.9642 - Val Acc: 0.7156
#
# Epoch 32/100
# --------------------
# Batch [40/80] - Loss: 0.0001 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.58s
# Train Loss: 0.4294 - Train Acc: 0.9703
# Val Loss: 11.1653 - Val Acc: 0.7406
#
# Epoch 33/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.40s
# Train Loss: 0.1616 - Train Acc: 0.9852
# Val Loss: 12.2639 - Val Acc: 0.7312
#
# Epoch 34/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0007 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.12s
# Train Loss: 0.1495 - Train Acc: 0.9812
# Val Loss: 12.2249 - Val Acc: 0.7031
#
# Epoch 35/100
# --------------------
# Batch [40/80] - Loss: 0.0663 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.88s
# Train Loss: 0.1652 - Train Acc: 0.9844
# Val Loss: 11.6495 - Val Acc: 0.7219
#
# Epoch 36/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.99s
# Train Loss: 0.2359 - Train Acc: 0.9867
# Val Loss: 9.6342 - Val Acc: 0.7625
#
# Epoch 37/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.04s
# Train Loss: 0.1012 - Train Acc: 0.9883
# Val Loss: 13.7346 - Val Acc: 0.7125
#
# Epoch 38/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.19s
# Train Loss: 0.2024 - Train Acc: 0.9836
# Val Loss: 11.2454 - Val Acc: 0.7250
#
# Epoch 39/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.73s
# Train Loss: 0.1485 - Train Acc: 0.9875
# Val Loss: 14.5592 - Val Acc: 0.6813
#
# Epoch 40/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.1512 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.16s
# Train Loss: 0.3946 - Train Acc: 0.9727
# Val Loss: 11.9292 - Val Acc: 0.7094
#
# Epoch 41/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.01s
# Train Loss: 0.8643 - Train Acc: 0.9602
# Val Loss: 12.4921 - Val Acc: 0.7031
#
# Epoch 42/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.92s
# Train Loss: 0.4795 - Train Acc: 0.9672
# Val Loss: 12.8129 - Val Acc: 0.7031
#
# Epoch 43/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 2.6304 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.84s
# Train Loss: 0.6996 - Train Acc: 0.9648
# Val Loss: 15.9000 - Val Acc: 0.6781
#
# Epoch 44/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.90s
# Train Loss: 0.2580 - Train Acc: 0.9805
# Val Loss: 12.3587 - Val Acc: 0.7250
#
# Epoch 45/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.69s
# Train Loss: 0.1426 - Train Acc: 0.9891
# Val Loss: 13.5420 - Val Acc: 0.6969
#
# Epoch 46/100
# --------------------
# Batch [40/80] - Loss: 0.9213 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.78s
# Train Loss: 0.1884 - Train Acc: 0.9852
# Val Loss: 10.6083 - Val Acc: 0.7125
#
# Epoch 47/100
# --------------------
# Batch [40/80] - Loss: 2.0113 - Acc: 0.9375
# Batch [80/80] - Loss: 0.5811 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.87s
# Train Loss: 0.1501 - Train Acc: 0.9844
# Val Loss: 12.3811 - Val Acc: 0.7344
#
# Epoch 48/100
# --------------------
# Batch [40/80] - Loss: 0.0086 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.73s
# Train Loss: 0.2538 - Train Acc: 0.9867
# Val Loss: 17.6422 - Val Acc: 0.6438
#
# Epoch 49/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.65s
# Train Loss: 0.2400 - Train Acc: 0.9797
# Val Loss: 16.2996 - Val Acc: 0.6562
#
# Epoch 50/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.40s
# Train Loss: 0.2658 - Train Acc: 0.9828
# Val Loss: 11.9159 - Val Acc: 0.7250
#
# Epoch 51/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.89s
# Train Loss: 0.1471 - Train Acc: 0.9914
# Val Loss: 12.2501 - Val Acc: 0.7344
#
# Epoch 52/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.84s
# Train Loss: 0.3019 - Train Acc: 0.9844
# Val Loss: 12.5027 - Val Acc: 0.7063
#
# Epoch 53/100
# --------------------
# Batch [40/80] - Loss: 0.0079 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.36s
# Train Loss: 0.3281 - Train Acc: 0.9766
# Val Loss: 11.7359 - Val Acc: 0.7312
#
# Epoch 54/100
# --------------------
# Batch [40/80] - Loss: 0.3309 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0088 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.81s
# Train Loss: 0.3872 - Train Acc: 0.9719
# Val Loss: 11.8659 - Val Acc: 0.7281
#
# Epoch 55/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.31s
# Train Loss: 0.2219 - Train Acc: 0.9820
# Val Loss: 17.2257 - Val Acc: 0.6750
#
# Epoch 56/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.05s
# Train Loss: 0.5328 - Train Acc: 0.9703
# Val Loss: 13.3156 - Val Acc: 0.7562
#
# Epoch 57/100
# --------------------
# Batch [40/80] - Loss: 0.3176 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.18s
# Train Loss: 0.3193 - Train Acc: 0.9789
# Val Loss: 14.6345 - Val Acc: 0.7281
#
# Epoch 58/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.87s
# Train Loss: 0.2718 - Train Acc: 0.9820
# Val Loss: 12.8022 - Val Acc: 0.7188
#
# Epoch 59/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 3.1438 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.47s
# Train Loss: 0.3261 - Train Acc: 0.9797
# Val Loss: 15.4093 - Val Acc: 0.6937
#
# Epoch 60/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 2.4232 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.95s
# Train Loss: 0.2435 - Train Acc: 0.9836
# Val Loss: 16.1162 - Val Acc: 0.7188
#
# Epoch 61/100
# --------------------
# Batch [40/80] - Loss: 0.0281 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.09s
# Train Loss: 0.2231 - Train Acc: 0.9867
# Val Loss: 14.5952 - Val Acc: 0.7031
#
# Epoch 62/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.5107 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.61s
# Train Loss: 0.1077 - Train Acc: 0.9859
# Val Loss: 15.2364 - Val Acc: 0.7188
#
# Epoch 63/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 1.3464 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.27s
# Train Loss: 0.1699 - Train Acc: 0.9859
# Val Loss: 13.6585 - Val Acc: 0.7281
#
# Epoch 64/100
# --------------------
# Batch [40/80] - Loss: 2.0893 - Acc: 0.8750
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.29s
# Train Loss: 0.1977 - Train Acc: 0.9828
# Val Loss: 14.4024 - Val Acc: 0.7312
#
# Epoch 65/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.33s
# Train Loss: 0.2728 - Train Acc: 0.9812
# Val Loss: 17.2837 - Val Acc: 0.6813
#
# Epoch 66/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0003 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.10s
# Train Loss: 0.2716 - Train Acc: 0.9773
# Val Loss: 17.8525 - Val Acc: 0.6656
#
# Epoch 67/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.52s
# Train Loss: 0.3124 - Train Acc: 0.9789
# Val Loss: 15.2783 - Val Acc: 0.7031
#
# Epoch 68/100
# --------------------
# Batch [40/80] - Loss: 1.6403 - Acc: 0.9375
# Batch [80/80] - Loss: 0.3279 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.15s
# Train Loss: 0.2424 - Train Acc: 0.9828
# Val Loss: 14.4196 - Val Acc: 0.7281
#
# Epoch 69/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0013 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.11s
# Train Loss: 0.4209 - Train Acc: 0.9820
# Val Loss: 21.0064 - Val Acc: 0.6781
#
# Epoch 70/100
# --------------------
# Batch [40/80] - Loss: 0.0029 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.41s
# Train Loss: 0.6258 - Train Acc: 0.9734
# Val Loss: 20.8004 - Val Acc: 0.6719
#
# Epoch 71/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 2.1614 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 12.29s
# Train Loss: 0.5910 - Train Acc: 0.9781
# Val Loss: 13.8367 - Val Acc: 0.7312
#
# Epoch 72/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.11s
# Train Loss: 0.4799 - Train Acc: 0.9812
# Val Loss: 17.3118 - Val Acc: 0.7188
#
# Epoch 73/100
# --------------------
# Batch [40/80] - Loss: 0.7433 - Acc: 0.9375
# Batch [80/80] - Loss: 1.0088 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.32s
# Train Loss: 0.1762 - Train Acc: 0.9859
# Val Loss: 14.8809 - Val Acc: 0.7281
#
# Epoch 74/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.09s
# Train Loss: 0.3898 - Train Acc: 0.9820
# Val Loss: 18.3255 - Val Acc: 0.6844
#
# Epoch 75/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.39s
# Train Loss: 0.0695 - Train Acc: 0.9914
# Val Loss: 17.9756 - Val Acc: 0.7125
#
# Epoch 76/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0059 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.24s
# Train Loss: 0.1736 - Train Acc: 0.9867
# Val Loss: 13.8333 - Val Acc: 0.7219
#
# Epoch 77/100
# --------------------
# Batch [40/80] - Loss: 1.8903 - Acc: 0.9375
# Batch [80/80] - Loss: 4.6910 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.58s
# Train Loss: 0.2415 - Train Acc: 0.9875
# Val Loss: 16.2900 - Val Acc: 0.7344
#
# Epoch 78/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.18s
# Train Loss: 0.2393 - Train Acc: 0.9891
# Val Loss: 13.7398 - Val Acc: 0.7250
#
# Epoch 79/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.84s
# Train Loss: 0.1642 - Train Acc: 0.9898
# Val Loss: 12.5325 - Val Acc: 0.7531
#
# Epoch 80/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.78s
# Train Loss: 0.1694 - Train Acc: 0.9906
# Val Loss: 20.5604 - Val Acc: 0.6906
#
# Epoch 81/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.39s
# Train Loss: 0.5037 - Train Acc: 0.9758
# Val Loss: 21.5106 - Val Acc: 0.6969
#
# Epoch 82/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0049 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.23s
# Train Loss: 0.9761 - Train Acc: 0.9672
# Val Loss: 19.4130 - Val Acc: 0.6781
#
# Epoch 83/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.80s
# Train Loss: 1.3518 - Train Acc: 0.9563
# Val Loss: 27.1234 - Val Acc: 0.6312
#
# Epoch 84/100
# --------------------
# Batch [40/80] - Loss: 1.3412 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.10s
# Train Loss: 1.1216 - Train Acc: 0.9508
# Val Loss: 25.3211 - Val Acc: 0.6219
#
# Epoch 85/100
# --------------------
# Batch [40/80] - Loss: 3.9165 - Acc: 0.9375
# Batch [80/80] - Loss: 0.2473 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.25s
# Train Loss: 1.0151 - Train Acc: 0.9547
# Val Loss: 16.5066 - Val Acc: 0.6844
#
# Epoch 86/100
# --------------------
# Batch [40/80] - Loss: 0.2926 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0012 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.94s
# Train Loss: 0.8759 - Train Acc: 0.9609
# Val Loss: 18.1366 - Val Acc: 0.6969
#
# Epoch 87/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0008 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.08s
# Train Loss: 1.1568 - Train Acc: 0.9578
# Val Loss: 19.9332 - Val Acc: 0.6844
#
# Epoch 88/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.11s
# Train Loss: 0.5257 - Train Acc: 0.9766
# Val Loss: 16.9185 - Val Acc: 0.7250
#
# Epoch 89/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.94s
# Train Loss: 0.4146 - Train Acc: 0.9750
# Val Loss: 15.9255 - Val Acc: 0.7344
#
# Epoch 90/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.88s
# Train Loss: 0.3614 - Train Acc: 0.9820
# Val Loss: 16.7770 - Val Acc: 0.7219
#
# Epoch 91/100
# --------------------
# Batch [40/80] - Loss: 0.0140 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.83s
# Train Loss: 0.2792 - Train Acc: 0.9844
# Val Loss: 20.6060 - Val Acc: 0.7031
#
# Epoch 92/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.00s
# Train Loss: 0.2934 - Train Acc: 0.9852
# Val Loss: 13.4965 - Val Acc: 0.7344
#
# Epoch 93/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.91s
# Train Loss: 0.1354 - Train Acc: 0.9891
# Val Loss: 17.2277 - Val Acc: 0.7406
#
# Epoch 94/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.94s
# Train Loss: 0.3784 - Train Acc: 0.9820
# Val Loss: 16.2539 - Val Acc: 0.6969
#
# Epoch 95/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.24s
# Train Loss: 0.1665 - Train Acc: 0.9906
# Val Loss: 19.7881 - Val Acc: 0.7250
#
# Epoch 96/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 1.4996 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.77s
# Train Loss: 0.1889 - Train Acc: 0.9883
# Val Loss: 14.7778 - Val Acc: 0.7125
#
# Epoch 97/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.97s
# Train Loss: 0.1298 - Train Acc: 0.9906
# Val Loss: 16.7302 - Val Acc: 0.7219
#
# Epoch 98/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.07s
# Train Loss: 0.0619 - Train Acc: 0.9945
# Val Loss: 18.4148 - Val Acc: 0.6844
#
# Epoch 99/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.82s
# Train Loss: 0.0344 - Train Acc: 0.9953
# Val Loss: 13.5733 - Val Acc: 0.7469
#
# Epoch 100/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.14s
# Train Loss: 0.1263 - Train Acc: 0.9930
# Val Loss: 14.2723 - Val Acc: 0.7562
#
# Training ConvFF model...
# Training on cuda
# Model: convff
#
# Epoch 1/100
# --------------------
# Batch [40/80] - Loss: 240.7404 - Acc: 0.1250
# Batch [80/80] - Loss: 54.7365 - Acc: 0.3125
#
# Epoch Summary:
# Time taken: 12.02s
# Train Loss: 132.3303 - Train Acc: 0.2469
# Val Loss: 69.3154 - Val Acc: 0.3094
#
# Epoch 2/100
# --------------------
# Batch [40/80] - Loss: 29.5078 - Acc: 0.4375
# Batch [80/80] - Loss: 15.9344 - Acc: 0.5000
#
# Epoch Summary:
# Time taken: 12.52s
# Train Loss: 33.8409 - Train Acc: 0.4992
# Val Loss: 25.7200 - Val Acc: 0.4906
#
# Epoch 3/100
# --------------------
# Batch [40/80] - Loss: 16.0138 - Acc: 0.6875
# Batch [80/80] - Loss: 4.5277 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 12.21s
# Train Loss: 11.8061 - Train Acc: 0.6953
# Val Loss: 20.6630 - Val Acc: 0.5813
#
# Epoch 4/100
# --------------------
# Batch [40/80] - Loss: 6.2681 - Acc: 0.8125
# Batch [80/80] - Loss: 3.7156 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 11.93s
# Train Loss: 7.2000 - Train Acc: 0.7352
# Val Loss: 11.8664 - Val Acc: 0.6406
#
# Epoch 5/100
# --------------------
# Batch [40/80] - Loss: 0.7935 - Acc: 0.8125
# Batch [80/80] - Loss: 3.2713 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 12.18s
# Train Loss: 3.1857 - Train Acc: 0.8367
# Val Loss: 7.7418 - Val Acc: 0.6906
#
# Epoch 6/100
# --------------------
# Batch [40/80] - Loss: 1.3733 - Acc: 0.7500
# Batch [80/80] - Loss: 1.7723 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 11.74s
# Train Loss: 1.9892 - Train Acc: 0.8672
# Val Loss: 10.8803 - Val Acc: 0.6562
#
# Epoch 7/100
# --------------------
# Batch [40/80] - Loss: 3.0496 - Acc: 0.8125
# Batch [80/80] - Loss: 1.0893 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.07s
# Train Loss: 2.2810 - Train Acc: 0.8711
# Val Loss: 11.4646 - Val Acc: 0.6406
#
# Epoch 8/100
# --------------------
# Batch [40/80] - Loss: 0.0613 - Acc: 0.9375
# Batch [80/80] - Loss: 1.0598 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.81s
# Train Loss: 1.3649 - Train Acc: 0.8969
# Val Loss: 8.1664 - Val Acc: 0.6750
#
# Epoch 9/100
# --------------------
# Batch [40/80] - Loss: 5.0026 - Acc: 0.8125
# Batch [80/80] - Loss: 1.1919 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.36s
# Train Loss: 0.9935 - Train Acc: 0.9172
# Val Loss: 9.6506 - Val Acc: 0.6781
#
# Epoch 10/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.59s
# Train Loss: 0.6073 - Train Acc: 0.9484
# Val Loss: 8.0343 - Val Acc: 0.7125
#
# Epoch 11/100
# --------------------
# Batch [40/80] - Loss: 0.5533 - Acc: 0.9375
# Batch [80/80] - Loss: 1.3257 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.72s
# Train Loss: 0.5141 - Train Acc: 0.9500
# Val Loss: 7.3849 - Val Acc: 0.7031
#
# Epoch 12/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.8696 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 11.52s
# Train Loss: 0.3877 - Train Acc: 0.9547
# Val Loss: 8.1802 - Val Acc: 0.6813
#
# Epoch 13/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0231 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.55s
# Train Loss: 0.4294 - Train Acc: 0.9555
# Val Loss: 7.0975 - Val Acc: 0.7000
#
# Epoch 14/100
# --------------------
# Batch [40/80] - Loss: 3.6437 - Acc: 0.8750
# Batch [80/80] - Loss: 0.3163 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.80s
# Train Loss: 0.4240 - Train Acc: 0.9570
# Val Loss: 6.6304 - Val Acc: 0.7219
#
# Epoch 15/100
# --------------------
# Batch [40/80] - Loss: 0.0109 - Acc: 1.0000
# Batch [80/80] - Loss: 0.4225 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.14s
# Train Loss: 0.1887 - Train Acc: 0.9750
# Val Loss: 7.2899 - Val Acc: 0.6906
#
# Epoch 16/100
# --------------------
# Batch [40/80] - Loss: 0.0256 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.69s
# Train Loss: 0.1503 - Train Acc: 0.9820
# Val Loss: 9.1411 - Val Acc: 0.7000
#
# Epoch 17/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0130 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.81s
# Train Loss: 0.1974 - Train Acc: 0.9812
# Val Loss: 9.0116 - Val Acc: 0.6906
#
# Epoch 18/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0009 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.13s
# Train Loss: 0.2991 - Train Acc: 0.9734
# Val Loss: 9.7695 - Val Acc: 0.6844
#
# Epoch 19/100
# --------------------
# Batch [40/80] - Loss: 0.0347 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 13.67s
# Train Loss: 0.2220 - Train Acc: 0.9727
# Val Loss: 9.6625 - Val Acc: 0.6813
#
# Epoch 20/100
# --------------------
# Batch [40/80] - Loss: 0.6524 - Acc: 0.9375
# Batch [80/80] - Loss: 2.6014 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 13.32s
# Train Loss: 0.1933 - Train Acc: 0.9820
# Val Loss: 7.7797 - Val Acc: 0.7156
#
# Epoch 21/100
# --------------------
# Batch [40/80] - Loss: 0.0173 - Acc: 1.0000
# Batch [80/80] - Loss: 0.7173 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 13.24s
# Train Loss: 0.3373 - Train Acc: 0.9680
# Val Loss: 8.2726 - Val Acc: 0.7125
#
# Epoch 22/100
# --------------------
# Batch [40/80] - Loss: 0.0002 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.83s
# Train Loss: 0.3050 - Train Acc: 0.9703
# Val Loss: 7.6617 - Val Acc: 0.7375
#
# Epoch 23/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.1344 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 13.09s
# Train Loss: 0.2539 - Train Acc: 0.9734
# Val Loss: 7.9340 - Val Acc: 0.7469
#
# Epoch 24/100
# --------------------
# Batch [40/80] - Loss: 1.6996 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 13.18s
# Train Loss: 0.4792 - Train Acc: 0.9609
# Val Loss: 8.4137 - Val Acc: 0.6937
#
# Epoch 25/100
# --------------------
# Batch [40/80] - Loss: 9.0682 - Acc: 0.8750
# Batch [80/80] - Loss: 2.4140 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 12.95s
# Train Loss: 0.6583 - Train Acc: 0.9555
# Val Loss: 8.4331 - Val Acc: 0.7063
#
# Epoch 26/100
# --------------------
# Batch [40/80] - Loss: 2.7633 - Acc: 0.8750
# Batch [80/80] - Loss: 3.5852 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.69s
# Train Loss: 0.8626 - Train Acc: 0.9477
# Val Loss: 14.1345 - Val Acc: 0.6062
#
# Epoch 27/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0832 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.42s
# Train Loss: 0.9553 - Train Acc: 0.9313
# Val Loss: 15.3731 - Val Acc: 0.6375
#
# Epoch 28/100
# --------------------
# Batch [40/80] - Loss: 2.4223 - Acc: 0.8125
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.78s
# Train Loss: 0.7249 - Train Acc: 0.9500
# Val Loss: 10.9567 - Val Acc: 0.6719
#
# Epoch 29/100
# --------------------
# Batch [40/80] - Loss: 0.5926 - Acc: 0.9375
# Batch [80/80] - Loss: 1.9297 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.61s
# Train Loss: 0.4938 - Train Acc: 0.9516
# Val Loss: 10.3226 - Val Acc: 0.6844
#
# Epoch 30/100
# --------------------
# Batch [40/80] - Loss: 2.4016 - Acc: 0.8750
# Batch [80/80] - Loss: 1.5111 - Acc: 0.8125
#
# Epoch Summary:
# Time taken: 11.86s
# Train Loss: 0.7680 - Train Acc: 0.9398
# Val Loss: 12.1274 - Val Acc: 0.6594
#
# Epoch 31/100
# --------------------
# Batch [40/80] - Loss: 0.4052 - Acc: 0.9375
# Batch [80/80] - Loss: 0.6204 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.65s
# Train Loss: 0.7276 - Train Acc: 0.9469
# Val Loss: 13.7351 - Val Acc: 0.6813
#
# Epoch 32/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 13.12s
# Train Loss: 0.4185 - Train Acc: 0.9703
# Val Loss: 11.4319 - Val Acc: 0.7000
#
# Epoch 33/100
# --------------------
# Batch [40/80] - Loss: 1.0123 - Acc: 0.8750
# Batch [80/80] - Loss: 0.9759 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.20s
# Train Loss: 0.6810 - Train Acc: 0.9477
# Val Loss: 11.0343 - Val Acc: 0.6875
#
# Epoch 34/100
# --------------------
# Batch [40/80] - Loss: 0.0009 - Acc: 1.0000
# Batch [80/80] - Loss: 0.3985 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.12s
# Train Loss: 1.4160 - Train Acc: 0.9383
# Val Loss: 19.5585 - Val Acc: 0.5750
#
# Epoch 35/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0022 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.59s
# Train Loss: 0.7665 - Train Acc: 0.9586
# Val Loss: 15.2527 - Val Acc: 0.6719
#
# Epoch 36/100
# --------------------
# Batch [40/80] - Loss: 0.0001 - Acc: 1.0000
# Batch [80/80] - Loss: 1.6192 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.79s
# Train Loss: 0.3373 - Train Acc: 0.9766
# Val Loss: 13.7626 - Val Acc: 0.6687
#
# Epoch 37/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.10s
# Train Loss: 0.2628 - Train Acc: 0.9789
# Val Loss: 11.7847 - Val Acc: 0.6906
#
# Epoch 38/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.98s
# Train Loss: 0.2672 - Train Acc: 0.9727
# Val Loss: 15.9752 - Val Acc: 0.6625
#
# Epoch 39/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.8963 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.30s
# Train Loss: 0.1334 - Train Acc: 0.9867
# Val Loss: 11.2434 - Val Acc: 0.7250
#
# Epoch 40/100
# --------------------
# Batch [40/80] - Loss: 0.0679 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.79s
# Train Loss: 0.1626 - Train Acc: 0.9836
# Val Loss: 10.8963 - Val Acc: 0.7250
#
# Epoch 41/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.14s
# Train Loss: 0.2576 - Train Acc: 0.9773
# Val Loss: 10.0607 - Val Acc: 0.6969
#
# Epoch 42/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.65s
# Train Loss: 0.1980 - Train Acc: 0.9820
# Val Loss: 12.0741 - Val Acc: 0.6844
#
# Epoch 43/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.45s
# Train Loss: 0.1720 - Train Acc: 0.9891
# Val Loss: 15.3630 - Val Acc: 0.6844
#
# Epoch 44/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.4227 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.59s
# Train Loss: 0.2381 - Train Acc: 0.9812
# Val Loss: 11.4616 - Val Acc: 0.7094
#
# Epoch 45/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.96s
# Train Loss: 0.1210 - Train Acc: 0.9883
# Val Loss: 10.3173 - Val Acc: 0.7406
#
# Epoch 46/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.08s
# Train Loss: 0.0321 - Train Acc: 0.9961
# Val Loss: 9.9164 - Val Acc: 0.7375
#
# Epoch 47/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.99s
# Train Loss: 0.0418 - Train Acc: 0.9914
# Val Loss: 9.5839 - Val Acc: 0.7406
#
# Epoch 48/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.67s
# Train Loss: 0.0722 - Train Acc: 0.9914
# Val Loss: 11.1553 - Val Acc: 0.7000
#
# Epoch 49/100
# --------------------
# Batch [40/80] - Loss: 1.5296 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.10s
# Train Loss: 0.1202 - Train Acc: 0.9875
# Val Loss: 11.3790 - Val Acc: 0.7031
#
# Epoch 50/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.42s
# Train Loss: 0.0818 - Train Acc: 0.9914
# Val Loss: 12.6972 - Val Acc: 0.6781
#
# Epoch 51/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.73s
# Train Loss: 0.1189 - Train Acc: 0.9859
# Val Loss: 11.5893 - Val Acc: 0.6875
#
# Epoch 52/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.79s
# Train Loss: 0.2046 - Train Acc: 0.9859
# Val Loss: 11.2861 - Val Acc: 0.7156
#
# Epoch 53/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.10s
# Train Loss: 0.0677 - Train Acc: 0.9922
# Val Loss: 9.8919 - Val Acc: 0.7156
#
# Epoch 54/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.5252 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.99s
# Train Loss: 0.2656 - Train Acc: 0.9781
# Val Loss: 12.9253 - Val Acc: 0.7000
#
# Epoch 55/100
# --------------------
# Batch [40/80] - Loss: 0.0002 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.88s
# Train Loss: 0.1939 - Train Acc: 0.9812
# Val Loss: 13.2260 - Val Acc: 0.6781
#
# Epoch 56/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.78s
# Train Loss: 0.2247 - Train Acc: 0.9820
# Val Loss: 11.0105 - Val Acc: 0.7375
#
# Epoch 57/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0002 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.75s
# Train Loss: 0.3182 - Train Acc: 0.9805
# Val Loss: 13.2608 - Val Acc: 0.6937
#
# Epoch 58/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.71s
# Train Loss: 0.3105 - Train Acc: 0.9766
# Val Loss: 14.0708 - Val Acc: 0.6875
#
# Epoch 59/100
# --------------------
# Batch [40/80] - Loss: 0.4948 - Acc: 0.8750
# Batch [80/80] - Loss: 1.5508 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.07s
# Train Loss: 0.3033 - Train Acc: 0.9781
# Val Loss: 13.3231 - Val Acc: 0.6937
#
# Epoch 60/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 2.9165 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.79s
# Train Loss: 1.1372 - Train Acc: 0.9367
# Val Loss: 25.7845 - Val Acc: 0.5687
#
# Epoch 61/100
# --------------------
# Batch [40/80] - Loss: 5.0147 - Acc: 0.8125
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.11s
# Train Loss: 1.3594 - Train Acc: 0.9328
# Val Loss: 20.1466 - Val Acc: 0.6219
#
# Epoch 62/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0014 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.79s
# Train Loss: 0.6189 - Train Acc: 0.9688
# Val Loss: 20.3899 - Val Acc: 0.6375
#
# Epoch 63/100
# --------------------
# Batch [40/80] - Loss: 2.2807 - Acc: 0.8750
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.84s
# Train Loss: 0.9135 - Train Acc: 0.9578
# Val Loss: 19.5751 - Val Acc: 0.6312
#
# Epoch 64/100
# --------------------
# Batch [40/80] - Loss: 0.2622 - Acc: 0.9375
# Batch [80/80] - Loss: 0.9634 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.12s
# Train Loss: 0.5096 - Train Acc: 0.9641
# Val Loss: 12.3808 - Val Acc: 0.7031
#
# Epoch 65/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.67s
# Train Loss: 0.2572 - Train Acc: 0.9797
# Val Loss: 14.3770 - Val Acc: 0.6969
#
# Epoch 66/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.01s
# Train Loss: 0.3056 - Train Acc: 0.9844
# Val Loss: 16.0711 - Val Acc: 0.6875
#
# Epoch 67/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.33s
# Train Loss: 0.0680 - Train Acc: 0.9906
# Val Loss: 14.8558 - Val Acc: 0.6969
#
# Epoch 68/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.00s
# Train Loss: 0.2957 - Train Acc: 0.9797
# Val Loss: 14.3893 - Val Acc: 0.7000
#
# Epoch 69/100
# --------------------
# Batch [40/80] - Loss: 1.5739 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0002 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.93s
# Train Loss: 0.1466 - Train Acc: 0.9891
# Val Loss: 15.9962 - Val Acc: 0.6781
#
# Epoch 70/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.87s
# Train Loss: 0.0891 - Train Acc: 0.9914
# Val Loss: 13.4522 - Val Acc: 0.7156
#
# Epoch 71/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.95s
# Train Loss: 0.1123 - Train Acc: 0.9891
# Val Loss: 12.8377 - Val Acc: 0.7031
#
# Epoch 72/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.55s
# Train Loss: 0.0606 - Train Acc: 0.9922
# Val Loss: 15.7447 - Val Acc: 0.6937
#
# Epoch 73/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.78s
# Train Loss: 0.1758 - Train Acc: 0.9891
# Val Loss: 21.9628 - Val Acc: 0.6250
#
# Epoch 74/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.34s
# Train Loss: 0.4243 - Train Acc: 0.9766
# Val Loss: 17.4584 - Val Acc: 0.6750
#
# Epoch 75/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.78s
# Train Loss: 0.2165 - Train Acc: 0.9875
# Val Loss: 13.2445 - Val Acc: 0.7094
#
# Epoch 76/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.18s
# Train Loss: 0.1251 - Train Acc: 0.9914
# Val Loss: 11.7436 - Val Acc: 0.7125
#
# Epoch 77/100
# --------------------
# Batch [40/80] - Loss: 0.4648 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.58s
# Train Loss: 0.1099 - Train Acc: 0.9930
# Val Loss: 12.4721 - Val Acc: 0.7312
#
# Epoch 78/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.20s
# Train Loss: 0.0551 - Train Acc: 0.9922
# Val Loss: 13.0574 - Val Acc: 0.7063
#
# Epoch 79/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.84s
# Train Loss: 0.0243 - Train Acc: 0.9953
# Val Loss: 14.1179 - Val Acc: 0.7188
#
# Epoch 80/100
# --------------------
# Batch [40/80] - Loss: 0.0006 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.61s
# Train Loss: 0.0271 - Train Acc: 0.9938
# Val Loss: 17.1116 - Val Acc: 0.6813
#
# Epoch 81/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.7961 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.58s
# Train Loss: 0.2161 - Train Acc: 0.9812
# Val Loss: 12.1316 - Val Acc: 0.7250
#
# Epoch 82/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0867 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.12s
# Train Loss: 0.1976 - Train Acc: 0.9836
# Val Loss: 17.1372 - Val Acc: 0.7188
#
# Epoch 83/100
# --------------------
# Batch [40/80] - Loss: 2.8644 - Acc: 0.9375
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.02s
# Train Loss: 0.1793 - Train Acc: 0.9867
# Val Loss: 11.6342 - Val Acc: 0.7281
#
# Epoch 84/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.25s
# Train Loss: 0.0971 - Train Acc: 0.9914
# Val Loss: 21.3099 - Val Acc: 0.6875
#
# Epoch 85/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.19s
# Train Loss: 0.5847 - Train Acc: 0.9695
# Val Loss: 17.3625 - Val Acc: 0.6875
#
# Epoch 86/100
# --------------------
# Batch [40/80] - Loss: 0.4517 - Acc: 0.9375
# Batch [80/80] - Loss: 1.4227 - Acc: 0.8750
#
# Epoch Summary:
# Time taken: 12.44s
# Train Loss: 0.2996 - Train Acc: 0.9797
# Val Loss: 15.5683 - Val Acc: 0.7094
#
# Epoch 87/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.02s
# Train Loss: 0.0619 - Train Acc: 0.9945
# Val Loss: 12.9308 - Val Acc: 0.7188
#
# Epoch 88/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.32s
# Train Loss: 0.0289 - Train Acc: 0.9961
# Val Loss: 14.9006 - Val Acc: 0.7094
#
# Epoch 89/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.48s
# Train Loss: 0.1449 - Train Acc: 0.9922
# Val Loss: 12.7478 - Val Acc: 0.7219
#
# Epoch 90/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.1888 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 12.35s
# Train Loss: 0.1908 - Train Acc: 0.9883
# Val Loss: 15.2249 - Val Acc: 0.6844
#
# Epoch 91/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.35s
# Train Loss: 0.0693 - Train Acc: 0.9914
# Val Loss: 15.3505 - Val Acc: 0.7000
#
# Epoch 92/100
# --------------------
# Batch [40/80] - Loss: 0.0028 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.42s
# Train Loss: 0.0908 - Train Acc: 0.9922
# Val Loss: 13.2439 - Val Acc: 0.7281
#
# Epoch 93/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.1309 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.64s
# Train Loss: 0.1280 - Train Acc: 0.9906
# Val Loss: 14.6014 - Val Acc: 0.7250
#
# Epoch 94/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.4447 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.53s
# Train Loss: 0.1865 - Train Acc: 0.9891
# Val Loss: 16.4090 - Val Acc: 0.6844
#
# Epoch 95/100
# --------------------
# Batch [40/80] - Loss: 0.0222 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0006 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.00s
# Train Loss: 0.1461 - Train Acc: 0.9891
# Val Loss: 16.3287 - Val Acc: 0.6687
#
# Epoch 96/100
# --------------------
# Batch [40/80] - Loss: 1.5625 - Acc: 0.8750
# Batch [80/80] - Loss: 2.0269 - Acc: 0.9375
#
# Epoch Summary:
# Time taken: 11.88s
# Train Loss: 0.2268 - Train Acc: 0.9852
# Val Loss: 12.9448 - Val Acc: 0.7312
#
# Epoch 97/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.37s
# Train Loss: 0.1074 - Train Acc: 0.9883
# Val Loss: 13.5489 - Val Acc: 0.7125
#
# Epoch 98/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.54s
# Train Loss: 0.1320 - Train Acc: 0.9922
# Val Loss: 16.8310 - Val Acc: 0.6844
#
# Epoch 99/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 12.11s
# Train Loss: 0.0754 - Train Acc: 0.9938
# Val Loss: 13.0611 - Val Acc: 0.7344
#
# Epoch 100/100
# --------------------
# Batch [40/80] - Loss: 0.0000 - Acc: 1.0000
# Batch [80/80] - Loss: 0.0000 - Acc: 1.0000
#
# Epoch Summary:
# Time taken: 11.89s
# Train Loss: 0.0629 - Train Acc: 0.9953
# Val Loss: 13.6558 - Val Acc: 0.6969
#
# Training complete! Plots have been saved to the 'model_comparison' directory.
